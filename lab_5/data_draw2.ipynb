# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
f = open("D:\ME_USER\Programming_2022\OS_labs_3_sem\lab_5\data1.txt");
title = f.readline().split(" ");

title_data = []
for i in range (len(title)):
    curr_data = []
    title_data.append(curr_data)

for line in f:
    line = line.split(" ");
    for i in range (len(title)):
        title_data[i].append(line[i]);

# %%
for i in range(len(title_data[6])):
    title_data[6][i] = float(title_data[6][i].split("0:")[1])

# %%
title_data[0] = list(map(float, title_data[0]))
title_data[1] = list(map(float, title_data[1]))
title_data[2] = list(map(float, title_data[2]))
title_data[3] = list(map(float, title_data[3]))
title_data[4] = list(map(float, title_data[4]))
title_data[5] = list(map(float, title_data[5]))
plt.plot(title_data[6], title_data[0], color = "green", label = title[0])
plt.plot(title_data[6], title_data[1], color = "yellow", label = title[1])
plt.plot(title_data[6], title_data[2], color = "red", label = title[2])
plt.plot(title_data[6], title_data[3], color = "orange", label = title[3])
plt.plot(title_data[6], title_data[4], color = "blue", label = title[4])
plt.plot(title_data[6], title_data[5], color = "violet", label = title[5])

plt.legend()
plt.minorticks_on()
plt.grid(True, which='both')
plt.grid(which='minor', color='gray', linestyle=':')

plt.show()

# %%
fig = plt.figure(figsize=(13,10))
axs = fig.subplots(5,1)

title_data[7] = list(map(float, title_data[7]))
title_data[8] = list(map(float, title_data[8]))
for i in range(len(title_data[9])):
    title_data[9][i] = float(title_data[9][i].split("g")[0])*100000

title_data[10] = list(map(float, title_data[10]))
title_data[11] = list(map(float, title_data[11]))

axs[0].plot(title_data[6], title_data[7], color = "green", label = title[7])
axs[1].plot(title_data[6], title_data[8], color = "yellow", label = title[8])
axs[2].plot(title_data[6], title_data[9], color = "red", label = title[9])
axs[3].plot(title_data[6], title_data[10], color = "orange", label = title[10])
axs[4].plot(title_data[6], title_data[11], color = "blue", label = title[11])

time_process = title_data[6]
axs[0].legend()
axs[1].legend()
axs[2].legend()
axs[3].legend()
axs[4].legend()
axs[0].minorticks_on()
axs[0].grid(True, which='both')
axs[0].grid(which='minor', color='gray', linestyle=':')
axs[1].minorticks_on()
axs[1].grid(True, which='both')
axs[1].grid(which='minor', color='gray', linestyle=':')
axs[2].minorticks_on()
axs[2].grid(True, which='both')
axs[2].grid(which='minor', color='gray', linestyle=':')
axs[3].minorticks_on()
axs[3].grid(True, which='both')
axs[3].grid(which='minor', color='gray', linestyle=':')
axs[4].minorticks_on()
axs[4].grid(True, which='both')
axs[4].grid(which='minor', color='gray', linestyle=':')
plt.show()

# %%
f = open("D:\ME_USER\Programming_2022\OS_labs_3_sem\lab_5\data2.txt");
title = f.readline().split(" ");

title_data = []
for i in range (len(title)):
    curr_data = []
    title_data.append(curr_data)

for line in f:
    line = line.split(" ");
    for i in range (len(title)):
        title_data[i].append(line[i]);

for i in range(len(title_data[0])):
    title_data[0][i] = float(title_data[0][i].split("0:")[1])

# %%
fig = plt.figure(figsize=(13,10))
axs = fig.subplots(5,1)

title_data[1] = list(map(float, title_data[1]))
title_data[2] = list(map(float, title_data[2]))
for i in range(len(title_data[3])):
    title_data[3][i] = float(title_data[3][i].split("g")[0])*100000

title_data[4] = list(map(float, title_data[4]))
title_data[5] = list(map(float, title_data[5]))

axs[0].plot(title_data[0], title_data[1], color = "green", label = title[1])
axs[1].plot(title_data[0], title_data[2], color = "yellow", label = title[2])
axs[2].plot(title_data[0], title_data[3], color = "red", label = title[3])
axs[3].plot(title_data[0], title_data[4], color = "orange", label = title[4])
axs[4].plot(title_data[0], title_data[5], color = "blue", label = title[5])

axs[0].legend()
axs[1].legend()
axs[2].legend()
axs[3].legend()
axs[4].legend()
axs[0].minorticks_on()
axs[0].grid(True, which='both')
axs[0].grid(which='minor', color='gray', linestyle=':')
axs[1].minorticks_on()
axs[1].grid(True, which='both')
axs[1].grid(which='minor', color='gray', linestyle=':')
axs[2].minorticks_on()
axs[2].grid(True, which='both')
axs[2].grid(which='minor', color='gray', linestyle=':')
axs[3].minorticks_on()
axs[3].grid(True, which='both')
axs[3].grid(which='minor', color='gray', linestyle=':')
axs[4].minorticks_on()
axs[4].grid(True, which='both')
axs[4].grid(which='minor', color='gray', linestyle=':')
plt.show()

# %%
f = open("D:\ME_USER\Programming_2022\OS_labs_3_sem\lab_5\data_process.txt");
title = f.readline().split(" ");

command_names = set()
data = []

for line in f:
    line = line.split(" ");
    for i in range (len(title)):
        command_names.add(line[i]);
f.close()
commands = []
for i in command_names:
    commands.append(i)
    data.append(['']*len(time_process))
f = open("D:\ME_USER\Programming_2022\OS_labs_3_sem\lab_5\data_process.txt");
title = f.readline().split(" ");

count = 0
for line in f:
    line = line.split(" ");
    for j in range(len(line)):
        for i in range(len(commands)):
            if commands[i] == line[j]:
                data[i][count] = (title[j])
    count += 1

# %%
plt.scatter(time_process, data[0], color = "green", label = commands[0])
plt.scatter(time_process, data[1], color = "red", label = commands[1])
plt.scatter(time_process, data[2], color = "orange", label = commands[2])
plt.scatter(time_process, data[3], color = "yellow", label = commands[3])
plt.scatter(time_process, data[4], color = "violet", label = commands[4])
plt.scatter(time_process, data[5], color = "blue", label = commands[5])
#plt.scatter(time_process, data[6], color = "crimson", label = commands[6])
plt.scatter(time_process, data[7], color = "cyan", label = commands[7])
plt.scatter(time_process, data[8], color = "black", label = commands[8])
plt.legend()
plt.minorticks_on()
plt.grid(True, which='both')
plt.grid(which='minor', color='gray', linestyle=':')

plt.show()
